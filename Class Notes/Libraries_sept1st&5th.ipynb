# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
lst1 = [12,23,34,45,56,67,78,89,90,110]
df1 = pd.DataFrame(lst1)
print(df1)
type(df1)
# Out:
#      0
# 0   12
# 1   23
# 2   34
# 3   45
# 4   56
# 5   67
# 6   78
# 7   89
# 8   90
# 9  110
# pandas.core.frame.DataFrame

# %%
lang = ['C','C++','Java','Python']
df2 = pd.DataFrame(lang)
df2
# Out:
#         0
# 0       C
# 1     C++
# 2    Java
# 3  Python

# %%
rating = [4,3,2,1]
df2[1] = rating
df2
# Out:
#         0  1
# 0       C  4
# 1     C++  3
# 2    Java  2
# 3  Python  1

# %%
df2.columns = ['language', 'rating']
df2
# Out:
#   language  rating
# 0        C       4
# 1      C++       3
# 2     Java       2
# 3   Python       1

# %%
# Create Dataframe from Dictionary
data = [{'a': 1, 'b': 2},{'a': 5, 'b': 10, 'c': 20}]
df2 = pd.DataFrame(data)
df3 = pd.DataFrame(data, index=['row1', 'row2'], columns=['a', 'b'])
df4 = pd.DataFrame(data, index=['row1', 'row2'], columns=['a', 'b' ,'c'])
df5 = pd.DataFrame(data, index=['row1', 'row2'], columns=['a', 'b' ,'c' , 'd'])

# %%
df2
# Out:
#    a   b     c
# 0  1   2   NaN
# 1  5  10  20.0

# %%
df3
# Out:
#       a   b
# row1  1   2
# row2  5  10

# %%
df4
# Out:
#       a   b     c
# row1  1   2   NaN
# row2  5  10  20.0

# %%
df5
# Out:
#       a   b     c   d
# row1  1   2   NaN NaN
# row2  5  10  20.0 NaN

# %%
df6 = pd.DataFrame({'ID':[1,2,3,4], 'Name':['Ramesh','Suresh','Naresh','Sukesh']})
df6
# Out:
#    ID    Name
# 0   1  Ramesh
# 1   2  Suresh
# 2   3  Naresh
# 3   4  Sukesh

# %%
df6['ID'], df6['Name']
# Out:
# (0    1
#  1    2
#  2    3
#  3    4
#  Name: ID, dtype: int64,
#  0    Ramesh
#  1    Suresh
#  2    Naresh
#  3    Sukesh
#  Name: Name, dtype: object)

# %%
dict1 = {'A': pd.Series([1,2,3,4], index = ['a','b','c','d']),
         'B': pd.Series([1,2,3,4,5], index = ['a','b','c','d','e'])
         }
df1 = pd.DataFrame(dict1)
df1
# Out:
#      A  B
# a  1.0  1
# b  2.0  2
# c  3.0  3
# d  4.0  4
# e  NaN  5

# %% [markdown]
# ## Dataframe of Random Numbers with date Indices

# %%
dates = pd.date_range(start='01-Aug-2023', end = '31-Aug-2023')

# %%
dates
# Out:
# DatetimeIndex(['2023-08-01', '2023-08-02', '2023-08-03', '2023-08-04',
#                '2023-08-05', '2023-08-06', '2023-08-07', '2023-08-08',
#                '2023-08-09', '2023-08-10', '2023-08-11', '2023-08-12',
#                '2023-08-13', '2023-08-14', '2023-08-15', '2023-08-16',
#                '2023-08-17', '2023-08-18', '2023-08-19', '2023-08-20',
#                '2023-08-21', '2023-08-22', '2023-08-23', '2023-08-24',
#                '2023-08-25', '2023-08-26', '2023-08-27', '2023-08-28',
#                '2023-08-29', '2023-08-30', '2023-08-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates = pd.date_range('today', periods = 7)
dates
# Out:
# DatetimeIndex(['2023-09-06 00:23:57.564805', '2023-09-07 00:23:57.564805',
#                '2023-09-08 00:23:57.564805', '2023-09-09 00:23:57.564805',
#                '2023-09-10 00:23:57.564805', '2023-09-11 00:23:57.564805',
#                '2023-09-12 00:23:57.564805'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates = pd.date_range('2023-08-25', periods = 7)
dates
# Out:
# DatetimeIndex(['2023-08-25', '2023-08-26', '2023-08-27', '2023-08-28',
#                '2023-08-29', '2023-08-30', '2023-08-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
M= np.random.random((7,7))
M
# Out:
# array([[0.95805016, 0.84095536, 0.95518232, 0.90775508, 0.18930936,
#         0.4380421 , 0.66644682],
#        [0.75139494, 0.21681989, 0.07226667, 0.1155777 , 0.29423032,
#         0.83599598, 0.6911019 ],
#        [0.82356502, 0.37560063, 0.75060517, 0.01980369, 0.14687001,
#         0.46563337, 0.53759253],
#        [0.36326634, 0.22354446, 0.36457306, 0.50931284, 0.28485708,
#         0.46487491, 0.68002824],
#        [0.1181103 , 0.60008182, 0.74535247, 0.17838128, 0.99819084,
#         0.43216644, 0.88163032],
#        [0.6990577 , 0.74634486, 0.0149066 , 0.57633396, 0.41233019,
#         0.97681161, 0.47765036],
#        [0.21169028, 0.59954889, 0.54693625, 0.88241554, 0.23590386,
#         0.05144164, 0.50363452]])

# %%
df = pd.DataFrame(M, index=dates)
df
# Out:
#                    0         1         2         3         4         5  \
# 2023-08-25  0.958050  0.840955  0.955182  0.907755  0.189309  0.438042
# 2023-08-26  0.751395  0.216820  0.072267  0.115578  0.294230  0.835996
# 2023-08-27  0.823565  0.375601  0.750605  0.019804  0.146870  0.465633
# 2023-08-28  0.363266  0.223544  0.364573  0.509313  0.284857  0.464875
# 2023-08-29  0.118110  0.600082  0.745352  0.178381  0.998191  0.432166
# 2023-08-30  0.699058  0.746345  0.014907  0.576334  0.412330  0.976812
# 2023-08-31  0.211690  0.599549  0.546936  0.882416  0.235904  0.051442
#
#                    6
# 2023-08-25  0.666447
# 2023-08-26  0.691102
# 2023-08-27  0.537593
# 2023-08-28  0.680028
# 2023-08-29  0.881630
# 2023-08-30  0.477650
# 2023-08-31  0.503635

# %%
df.columns = ['C1','C2','C3','C4','C5','C6','C7']
df
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-25  0.958050  0.840955  0.955182  0.907755  0.189309  0.438042
# 2023-08-26  0.751395  0.216820  0.072267  0.115578  0.294230  0.835996
# 2023-08-27  0.823565  0.375601  0.750605  0.019804  0.146870  0.465633
# 2023-08-28  0.363266  0.223544  0.364573  0.509313  0.284857  0.464875
# 2023-08-29  0.118110  0.600082  0.745352  0.178381  0.998191  0.432166
# 2023-08-30  0.699058  0.746345  0.014907  0.576334  0.412330  0.976812
# 2023-08-31  0.211690  0.599549  0.546936  0.882416  0.235904  0.051442
#
#                   C7
# 2023-08-25  0.666447
# 2023-08-26  0.691102
# 2023-08-27  0.537593
# 2023-08-28  0.680028
# 2023-08-29  0.881630
# 2023-08-30  0.477650
# 2023-08-31  0.503635

# %%
df.sort_values(by='C1',ascending=True)
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-29  0.118110  0.600082  0.745352  0.178381  0.998191  0.432166
# 2023-08-31  0.211690  0.599549  0.546936  0.882416  0.235904  0.051442
# 2023-08-28  0.363266  0.223544  0.364573  0.509313  0.284857  0.464875
# 2023-08-30  0.699058  0.746345  0.014907  0.576334  0.412330  0.976812
# 2023-08-26  0.751395  0.216820  0.072267  0.115578  0.294230  0.835996
# 2023-08-27  0.823565  0.375601  0.750605  0.019804  0.146870  0.465633
# 2023-08-25  0.958050  0.840955  0.955182  0.907755  0.189309  0.438042
#
#                   C7
# 2023-08-29  0.881630
# 2023-08-31  0.503635
# 2023-08-28  0.680028
# 2023-08-30  0.477650
# 2023-08-26  0.691102
# 2023-08-27  0.537593
# 2023-08-25  0.666447

# %%
df.sort_values(by='C1',ascending=False)

# %%
dict1 = {'A': pd.Series([1,2,3,4], index = ['a','b','c','d']),
         'B': pd.Series([1,2,3,4,5], index = ['a','b','c','d','e'])
         }
df1 = pd.DataFrame(dict1)
df1
# Out:
#      A  B
# a  1.0  1
# b  2.0  2
# c  3.0  3
# d  4.0  4
# e  NaN  5

# %%
del df1['B']  #deletes the column B
df1
# Out:
#      A
# a  1.0
# b  2.0
# c  3.0
# d  4.0
# e  NaN

# %%
dict = {'A' : pd.Series([1, 2, 3,11], index=['a', 'b', 'c','d']),
'B' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])}
df12 = pd.DataFrame(dict)
df12
# Out:
#     A  B
# a   1  1
# b   2  2
# c   3  3
# d  11  4

# %%
df12.drop(['A'], axis=1) # axis=0 => rows,  axis=1 => columns
df12
# Out:
#     A  B
# a   1  1
# b   2  2
# c   3  3
# d  11  4

# %%
df12.drop(['A'], axis=1, inplace=True) # axis=0 => rows,  axis=1 => columns
df12
# Out:
#    B
# a  1
# b  2
# c  3
# d  4

# %%
df12.drop(['c'], axis=0, inplace=True) # axis=0 => rows,  axis=1 => columns
df12
# Out:
#    B
# a  1
# b  2
# d  4

# %%
col1 = np.linspace(10, 100, 30)
col2 = np.random.randint(10,100,30)
df10 = pd.DataFrame({"C1" : col1 , "C2" :col2})
df10
# Out:
#             C1  C2
# 0    10.000000  33
# 1    13.103448  52
# 2    16.206897  51
# 3    19.310345  89
# 4    22.413793  79
# 5    25.517241  55
# 6    28.620690  46
# 7    31.724138  91
# 8    34.827586  51
# 9    37.931034  22
# 10   41.034483  68
# 11   44.137931  28
# 12   47.241379  92
# 13   50.344828  19
# 14   53.448276  57
# 15   56.551724  13
# 16   59.655172  38
# 17   62.758621  68
# 18   65.862069  41
# 19   68.965517  93
# 20   72.068966  79
# 21   75.172414  88
# 22   78.275862  46
# 23   81.379310  27
# 24   84.482759  37
# 25   87.586207  52
# 26   90.689655  42
# 27   93.793103  36
# 28   96.896552  62
# 29  100.000000  25

# %%
df10 = df10.drop([17,18,19], axis=0)
df10
# Out:
#             C1  C2
# 0    10.000000  33
# 1    13.103448  52
# 2    16.206897  51
# 3    19.310345  89
# 4    22.413793  79
# 5    25.517241  55
# 6    28.620690  46
# 7    31.724138  91
# 8    34.827586  51
# 9    37.931034  22
# 10   41.034483  68
# 11   44.137931  28
# 12   47.241379  92
# 13   50.344828  19
# 14   53.448276  57
# 15   56.551724  13
# 16   59.655172  38
# 20   72.068966  79
# 21   75.172414  88
# 22   78.275862  46
# 23   81.379310  27
# 24   84.482759  37
# 25   87.586207  52
# 26   90.689655  42
# 27   93.793103  36
# 28   96.896552  62
# 29  100.000000  25

# %%
df10
# Out:
#             C1  C2
# 0    10.000000  33
# 1    13.103448  52
# 2    16.206897  51
# 3    19.310345  89
# 4    22.413793  79
# 5    25.517241  55
# 6    28.620690  46
# 7    31.724138  91
# 8    34.827586  51
# 9    37.931034  22
# 10   41.034483  68
# 11   44.137931  28
# 12   47.241379  92
# 13   50.344828  19
# 14   53.448276  57
# 15   56.551724  13
# 16   59.655172  38
# 20   72.068966  79
# 21   75.172414  88
# 22   78.275862  46
# 23   81.379310  27
# 24   84.482759  37
# 25   87.586207  52
# 26   90.689655  42
# 27   93.793103  36
# 28   96.896552  62
# 29  100.000000  25

# %%
df10.drop([16], axis=0, inplace=True)
df10
# Out:
#             C1  C2
# 0    10.000000  33
# 1    13.103448  52
# 2    16.206897  51
# 3    19.310345  89
# 4    22.413793  79
# 5    25.517241  55
# 6    28.620690  46
# 7    31.724138  91
# 8    34.827586  51
# 9    37.931034  22
# 10   41.034483  68
# 11   44.137931  28
# 12   47.241379  92
# 13   50.344828  19
# 14   53.448276  57
# 15   56.551724  13
# 20   72.068966  79
# 21   75.172414  88
# 22   78.275862  46
# 23   81.379310  27
# 24   84.482759  37
# 25   87.586207  52
# 26   90.689655  42
# 27   93.793103  36
# 28   96.896552  62
# 29  100.000000  25

# %%
df10.drop(df10.index[5], inplace=True)

# %%
df10
# Out:
#             C1  C2
# 0    10.000000  33
# 1    13.103448  52
# 2    16.206897  51
# 3    19.310345  89
# 4    22.413793  79
# 6    28.620690  46
# 7    31.724138  91
# 8    34.827586  51
# 9    37.931034  22
# 10   41.034483  68
# 11   44.137931  28
# 12   47.241379  92
# 13   50.344828  19
# 14   53.448276  57
# 15   56.551724  13
# 20   72.068966  79
# 21   75.172414  88
# 22   78.275862  46
# 23   81.379310  27
# 24   84.482759  37
# 25   87.586207  52
# 26   90.689655  42
# 27   93.793103  36
# 28   96.896552  62
# 29  100.000000  25

# %%
df10.iloc[10:15]
# Out:
#            C1  C2
# 11  44.137931  28
# 12  47.241379  92
# 13  50.344828  19
# 14  53.448276  57
# 15  56.551724  13

# %%
df10.loc[10:15, 'C1']       #Location
# Out:
# 10    41.034483
# 11    44.137931
# 12    47.241379
# 13    50.344828
# 14    53.448276
# 15    56.551724
# Name: C1, dtype: float64

# %%
df10.iloc[10:15, 0]   #index location
# Out:
# 11    44.137931
# 12    47.241379
# 13    50.344828
# 14    53.448276
# 15    56.551724
# Name: C1, dtype: float64

# %%
df10.loc[10:,'C1':]
# Out:
#             C1  C2
# 10   41.034483  68
# 11   44.137931  28
# 12   47.241379  92
# 13   50.344828  19
# 14   53.448276  57
# 15   56.551724  13
# 20   72.068966  79
# 21   75.172414  88
# 22   78.275862  46
# 23   81.379310  27
# 24   84.482759  37
# 25   87.586207  52
# 26   90.689655  42
# 27   93.793103  36
# 28   96.896552  62
# 29  100.000000  25

# %%
df10.iloc[10:, 0:]
# Out:
#             C1  C2
# 11   44.137931  28
# 12   47.241379  92
# 13   50.344828  19
# 14   53.448276  57
# 15   56.551724  13
# 20   72.068966  79
# 21   75.172414  88
# 22   78.275862  46
# 23   81.379310  27
# 24   84.482759  37
# 25   87.586207  52
# 26   90.689655  42
# 27   93.793103  36
# 28   96.896552  62
# 29  100.000000  25

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
M= np.random.random((7,7))
M
# Out:
# array([[0.04365573, 0.37230355, 0.73782456, 0.83367013, 0.13454302,
#         0.32162743, 0.17324273],
#        [0.98438169, 0.00696433, 0.3297407 , 0.38131332, 0.65241985,
#         0.98716658, 0.01800592],
#        [0.13905613, 0.19921845, 0.80646989, 0.87017339, 0.3000186 ,
#         0.43997023, 0.66118811],
#        [0.23291568, 0.47292386, 0.12035503, 0.86470821, 0.40325371,
#         0.44968314, 0.55176735],
#        [0.48584559, 0.03208765, 0.15378   , 0.8886662 , 0.06530046,
#         0.96866169, 0.20466061],
#        [0.38088105, 0.30218189, 0.79115273, 0.48978782, 0.29250397,
#         0.97126308, 0.2013929 ],
#        [0.59664504, 0.68017383, 0.67216392, 0.59143581, 0.52442393,
#         0.13022008, 0.01708656]])

# %%
df = pd.DataFrame(M, index=dates)
df
# Out:
#                    0         1         2         3         4         5  \
# 2023-08-25  0.958050  0.840955  0.955182  0.907755  0.189309  0.438042
# 2023-08-26  0.751395  0.216820  0.072267  0.115578  0.294230  0.835996
# 2023-08-27  0.823565  0.375601  0.750605  0.019804  0.146870  0.465633
# 2023-08-28  0.363266  0.223544  0.364573  0.509313  0.284857  0.464875
# 2023-08-29  0.118110  0.600082  0.745352  0.178381  0.998191  0.432166
# 2023-08-30  0.699058  0.746345  0.014907  0.576334  0.412330  0.976812
# 2023-08-31  0.211690  0.599549  0.546936  0.882416  0.235904  0.051442
#
#                    6
# 2023-08-25  0.666447
# 2023-08-26  0.691102
# 2023-08-27  0.537593
# 2023-08-28  0.680028
# 2023-08-29  0.881630
# 2023-08-30  0.477650
# 2023-08-31  0.503635

# %%
df.columns = ['C1','C2','C3','C4','C5','C6','C7']
df
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-25  0.958050  0.840955  0.955182  0.907755  0.189309  0.438042
# 2023-08-26  0.751395  0.216820  0.072267  0.115578  0.294230  0.835996
# 2023-08-27  0.823565  0.375601  0.750605  0.019804  0.146870  0.465633
# 2023-08-28  0.363266  0.223544  0.364573  0.509313  0.284857  0.464875
# 2023-08-29  0.118110  0.600082  0.745352  0.178381  0.998191  0.432166
# 2023-08-30  0.699058  0.746345  0.014907  0.576334  0.412330  0.976812
# 2023-08-31  0.211690  0.599549  0.546936  0.882416  0.235904  0.051442
#
#                   C7
# 2023-08-25  0.666447
# 2023-08-26  0.691102
# 2023-08-27  0.537593
# 2023-08-28  0.680028
# 2023-08-29  0.881630
# 2023-08-30  0.477650
# 2023-08-31  0.503635

# %%
df.loc[:,'C4':]
# Out:
#                   C4        C5        C6        C7
# 2023-08-25  0.907755  0.189309  0.438042  0.666447
# 2023-08-26  0.115578  0.294230  0.835996  0.691102
# 2023-08-27  0.019804  0.146870  0.465633  0.537593
# 2023-08-28  0.509313  0.284857  0.464875  0.680028
# 2023-08-29  0.178381  0.998191  0.432166  0.881630
# 2023-08-30  0.576334  0.412330  0.976812  0.477650
# 2023-08-31  0.882416  0.235904  0.051442  0.503635

# %%
df.loc[:,'C4':]
# Out:
#                   C4        C5        C6        C7
# 2023-08-25  0.907755  0.189309  0.438042  0.666447
# 2023-08-26  0.115578  0.294230  0.835996  0.691102
# 2023-08-27  0.019804  0.146870  0.465633  0.537593
# 2023-08-28  0.509313  0.284857  0.464875  0.680028
# 2023-08-29  0.178381  0.998191  0.432166  0.881630
# 2023-08-30  0.576334  0.412330  0.976812  0.477650
# 2023-08-31  0.882416  0.235904  0.051442  0.503635

# %%
df.loc['25-08-2023':'25-08-2023','C1':'C1']
# Out:
# <ipython-input-31-67d2a7753ad7>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['25-08-2023':'25-08-2023','C1':'C1']
#                  C1
# 2023-08-25  0.95805

# %%
df.loc['26-08-2023':'26-08-2023','C2':'C2']
# Out:
# <ipython-input-32-1fd126cf03ec>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['26-08-2023':'26-08-2023','C2':'C2']
#                  C2
# 2023-08-26  0.21682

# %%
df.loc['27-08-2023':'27-08-2023','C3':'C3']
# Out:
# <ipython-input-44-0598eea2a8b0>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['27-08-2023':'27-08-2023','C3':'C3']
#                   C3
# 2023-08-27  0.750605

# %%
df.loc['28-08-2023':'28-08-2023','C4':'C4']
# Out:
# <ipython-input-43-97a2393ef63f>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['28-08-2023':'28-08-2023','C4':'C4']
#                   C4
# 2023-08-28  0.509313

# %%
df.loc['29-08-2023':'29-08-2023','C5':'C5']
# Out:
# <ipython-input-42-d737984eb42f>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['29-08-2023':'29-08-2023','C5':'C5']
#                   C5
# 2023-08-29  0.998191

# %%
df.loc['30-08-2023':'30-08-2023','C6':'C6']
# Out:
# <ipython-input-41-999a0150c3ba>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['30-08-2023':'30-08-2023','C6':'C6']
#                   C6
# 2023-08-30  0.976812

# %%
df.loc['31-08-2023':'31-08-2023','C7':'C7']
# Out:
# <ipython-input-40-acca78fa93ce>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['31-08-2023':'31-08-2023','C7':'C7']
#                   C7
# 2023-08-31  0.503635

# %%
df.loc['25-08-2023':'25-08-2023','C7':'C7']
# Out:
# <ipython-input-39-f8296650380d>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['25-08-2023':'25-08-2023','C7':'C7']
#                   C7
# 2023-08-25  0.666447

# %%
df.loc['26-08-2023':'26-08-2023','C6':'C6']
# Out:
# <ipython-input-38-e8718737b6fc>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['26-08-2023':'26-08-2023','C6':'C6']
#                   C6
# 2023-08-26  0.835996

# %%
df.loc['27-08-2023':'27-08-2023','C5':'C5']
# Out:
# <ipython-input-37-bca961938129>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['27-08-2023':'27-08-2023','C5':'C5']
#                  C5
# 2023-08-27  0.14687

# %%
df.loc['28-08-2023':'28-08-2023','C4':'C4']
# Out:
# <ipython-input-36-97a2393ef63f>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['28-08-2023':'28-08-2023','C4':'C4']
#                   C4
# 2023-08-28  0.509313

# %%
df.loc['29-08-2023':'29-08-2023','C3':'C3']
# Out:
# <ipython-input-35-5dbebb6eca1f>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['29-08-2023':'29-08-2023','C3':'C3']
#                   C3
# 2023-08-29  0.745352

# %%
df.loc['30-08-2023':'30-08-2023','C2':'C2']
# Out:
# <ipython-input-34-c519add2ac00>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['30-08-2023':'30-08-2023','C2':'C2']
#                   C2
# 2023-08-30  0.746345

# %%
df.loc['31-08-2023':'31-08-2023','C1':'C1']
# Out:
# <ipython-input-33-38e3a8da8904>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['31-08-2023':'31-08-2023','C1':'C1']
#                  C1
# 2023-08-31  0.21169

# %%
df
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-25  0.958050  0.840955  0.955182  0.907755  0.189309  0.438042
# 2023-08-26  0.751395  0.216820  0.072267  0.115578  0.294230  0.835996
# 2023-08-27  0.823565  0.375601  0.750605  0.019804  0.146870  0.465633
# 2023-08-28  0.363266  0.223544  0.364573  0.509313  0.284857  0.464875
# 2023-08-29  0.118110  0.600082  0.745352  0.178381  0.998191  0.432166
# 2023-08-30  0.699058  0.746345  0.014907  0.576334  0.412330  0.976812
# 2023-08-31  0.211690  0.599549  0.546936  0.882416  0.235904  0.051442
#
#                   C7
# 2023-08-25  0.666447
# 2023-08-26  0.691102
# 2023-08-27  0.537593
# 2023-08-28  0.680028
# 2023-08-29  0.881630
# 2023-08-30  0.477650
# 2023-08-31  0.503635

# %%
df.iloc[:,:]
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-25  0.958050  0.840955  0.955182  0.907755  0.189309  0.438042
# 2023-08-26  0.751395  0.216820  0.072267  0.115578  0.294230  0.835996
# 2023-08-27  0.823565  0.375601  0.750605  0.019804  0.146870  0.465633
# 2023-08-28  0.363266  0.223544  0.364573  0.509313  0.284857  0.464875
# 2023-08-29  0.118110  0.600082  0.745352  0.178381  0.998191  0.432166
# 2023-08-30  0.699058  0.746345  0.014907  0.576334  0.412330  0.976812
# 2023-08-31  0.211690  0.599549  0.546936  0.882416  0.235904  0.051442
#
#                   C7
# 2023-08-25  0.666447
# 2023-08-26  0.691102
# 2023-08-27  0.537593
# 2023-08-28  0.680028
# 2023-08-29  0.881630
# 2023-08-30  0.477650
# 2023-08-31  0.503635

# %%
df.iloc[3:,:]  #uses index value instead of actual value

# %%
df.iloc[:3,:]

# %%
df.iloc[:4,:]

# %%
df.iloc[:,3:]

# %%
df.iloc[:,:4]

# %%
df.iloc[:,:2]

# %%
df
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-25  0.958050  0.840955  0.955182  0.907755  0.189309  0.438042
# 2023-08-26  0.751395  0.216820  0.072267  0.115578  0.294230  0.835996
# 2023-08-27  0.823565  0.375601  0.750605  0.019804  0.146870  0.465633
# 2023-08-28  0.363266  0.223544  0.364573  0.509313  0.284857  0.464875
# 2023-08-29  0.118110  0.600082  0.745352  0.178381  0.998191  0.432166
# 2023-08-30  0.699058  0.746345  0.014907  0.576334  0.412330  0.976812
# 2023-08-31  0.211690  0.599549  0.546936  0.882416  0.235904  0.051442
#
#                   C7
# 2023-08-25  0.666447
# 2023-08-26  0.691102
# 2023-08-27  0.537593
# 2023-08-28  0.680028
# 2023-08-29  0.881630
# 2023-08-30  0.477650
# 2023-08-31  0.503635

# %%
df.iloc[6:,6:]

# %%
df.iloc[5:6,5:6]

# %%
df.iloc[4:5,4:5]

# %%
df.iloc[3:4,3:4]

# %%
df.iloc[2:3,2:3]

# %%
df.iloc[1:2,1:2]

# %%
df.iloc[0:1,0:1]

# %%
path = '/content/Churn_Modelling.csv'
df_churn_mod = pd.read_csv(path)
df_churn_mod
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
df_churn_mod.iloc[:100,:10]

# %%
df_churn_mod.iloc[50:,8:9]

# %%
df_churn_mod.iloc[:10,5:6]

# %%
df_churn_mod.iloc[:10,4:5]
# Out:
#   Geography
# 0    France
# 1     Spain
# 2    France
# 3    France
# 4     Spain
# 5     Spain
# 6    France
# 7   Germany
# 8    France
# 9    France

# %%
df_churn_mod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df_churn_mod.describe()

# %%
df_churn_mod.describe

# %%
df_churn_mod.size
# Out:
# 140000

# %%
df_churn_mod.ndim
# Out:
# 2

# %%
df_churn_mod.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df_churn_mod.shape

# %%
df_churn_mod.describe(include='all')

# %%
df_churn_mod.dtypes

# %%
df_churn_mod.count

# %%
df_churn_mod.isnull()

# %%
df_churn_mod.isnull().sum(axis=None)

# %%
df_churn_mod.sum(axis=None)

# %%
df_churn_mod.CreditScore

# %%
df_churn_mod['CreditScore']  #different way

# %%
df_churn_mod.CreditScore, df_churn_mod.Geography

# %%
df_churn_mod.CreditScore, df_churn_mod.Geography, df_churn_mod.Balance

# %%
df_churn_mod[['CreditScore','Geography','Balance']]

# %% [markdown]
# # Data Selection based on Condition

# %%
df_churn_mod[df_churn_mod.Gender=='Male']

# %%
df_churn_mod[(df_churn_mod.Gender=='Male') & (df_churn_mod.Age >= 45)]

# %%
df_churn_mod[(df_churn_mod.Gender=='Male') & (df_churn_mod.Age >= 45) & (df_churn_mod.Balance > 100000)]
